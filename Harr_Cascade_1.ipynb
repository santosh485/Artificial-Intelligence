# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('g.jpg')
image =cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(30,30))
plt.imshow(image)

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(30,30))
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray,1.3,5)
eyes = eye_cascade.detectMultiScale(gray,1.1,3)

# %%
print(faces)
print(len(faces))
# Out:
# [[233  43  52  52]
#  [323  77  51  51]
#  [112  94  52  52]
#  [ 87  23  49  49]
#  [148  29  52  52]
#  [ 36  65  56  56]]
# 6

# %%
copy_image = np.copy(image)
print(copy_image)
for (x,y,w,h) in faces:
    images = cv2.rectangle(copy_image,(x,y),(x+w,y+h),(0,0,255),5)
    for (ex,ey,ew,eh) in eyes:
        images = cv2.rectangle(images,(ex,ey),(ex+ew,ey+eh),(255,0,0),3)
plt.figure(figsize=(20,20))
plt.imshow(images)
# Out:
# [[[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [253 253 253]
#   [253 253 253]
#   [253 253 253]]
#
#  [[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [253 253 253]
#   [253 253 253]
#   [253 253 253]]
#
#  [[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [253 253 253]
#   [253 253 253]
#   [253 253 253]]
#
#  ...
#
#  [[ 52  87 127]
#   [ 51  86 124]
#   [ 57  92 130]
#   ...
#   [129 148 162]
#   [237 250 255]
#   [248 255 255]]
#
#  [[ 65  98 139]
#   [ 58  93 131]
#   [ 59  93 131]
#   ...
#   [110 129 143]
#   [223 236 244]
#   [244 253 255]]
#
#  [[ 74 106 145]
#   [ 63  97 135]
#   [ 57  89 128]
#   ...
#   [ 99 117 129]
#   [217 228 234]
#   [243 251 254]]]

# %%
copy_image = np.copy(image)
for (x,y,w,h) in faces:

    images = cv2.rectangle(copy_image,(x,y),(x+w,y+h),(0,0,255),5)
    for (ex,ey,ew,eh) in eyes:
        images = cv2.rectangle(images,(ex,ey),(ex+ew,ey+eh),(255,0,0),3)
plt.figure(figsize=(20,20))
plt.imshow(images)
